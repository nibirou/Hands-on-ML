# %% [markdown]
# # 第13章 集成学习与梯度提升树
# 通过将不同算法得到的模型按某些方式进行组合，
# 取长补短，从而获得比任一单个模型表现都要好的模型，这就是集成学 (ensemble learning)
# 的思想 。在表 3- 的例子中，我们采用了最简单的多数投票制的集成方法 。接下来，我们介绍
# 几种实践中常用的集成学习方法。
#
# ## 13.1 自举聚合与随机森林
# 回顾第6章交叉验证方法，将
